# %% [markdown]
# # Image stitching (Panorama Maker)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
#Read the images from your directory
dim=(1024,768)
left=cv2.imread('1.jpg',cv2.IMREAD_COLOR)
left=cv2.resize(left,dim,interpolation = cv2.INTER_AREA)   #ReSize to (1024,768)
right=cv2.imread('2.jpg',cv2.IMREAD_COLOR)
right=cv2.resize(right,dim,interpolation = cv2.INTER_AREA) #ReSize to (1024,768)
last=cv2.imread('3.jpg',cv2.IMREAD_COLOR)
last=cv2.resize(left,dim,interpolation = cv2.INTER_AREA)
images=[]
images.append(left)
images.append(right)
images.append(last)

# %%
#stitcher = cv2.createStitcher()
stitcher = cv2.Stitcher.create()
ret,pano = stitcher.stitch(images)

if ret==cv2.STITCHER_OK:
    cv2_imshow(pano)
    #cv2.waitKey()
    cv2.destroyAllWindows()
else:
    print("Error during Stitching")
# Out:
# <PIL.Image.Image image mode=RGB size=1577x878 at 0x7F5A5630DFD0>
